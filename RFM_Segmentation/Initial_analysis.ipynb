# %%
import pandas as pd, os, numpy as np, matplotlib.pyplot as plt

cur_dir = os.path.abspath('')
dataset_path = os.path.join(cur_dir,'..','Datasets/online+retail+ii/online_retail_II.xlsx')

# %%
data_df = pd.read_excel(dataset_path)

# %%
data_df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
for column in data_df.columns:
    na_index = pd.isna(data_df[[column]]).values
    if np.sum(na_index)>0:
        na_df = data_df.loc[na_index]
        print(na_df)
        # for column2 in na_df.columns:
        #     if column==column2: continue
        #     print(na_df[column2].unique())
        print('-'*100)
# Out:
#        Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 470     489521     21646         NaN       -50 2009-12-01 11:44:00    0.0
# 3114    489655     20683         NaN       -44 2009-12-01 17:26:00    0.0
# 3161    489659     21350         NaN       230 2009-12-01 17:39:00    0.0
# 3731    489781     84292         NaN        17 2009-12-02 11:45:00    0.0
# 4296    489806     18010         NaN      -770 2009-12-02 12:42:00    0.0
# ...        ...       ...         ...       ...                 ...    ...
# 524730  538141     22218         NaN         2 2010-12-09 15:58:00    0.0
# 524731  538143    84534B         NaN         1 2010-12-09 15:58:00    0.0
# 525231  538159     21324         NaN       -18 2010-12-09 17:17:00    0.0
# 525232  538158     20892         NaN       -32 2010-12-09 17:17:00    0.0
# 525233  538160     20956         NaN       288 2010-12-09 17:18:00    0.0
#
#         Customer ID         Country
# 470             NaN  United Kingdom
# ...

# %%
a = data_df.assign(Total_bought=lambda x: x.Quantity*x.Price)#.groupby("Customer ID")[["Total_bought"]].sum()
a.Total_bought.idxmin()
# Out:
# 179403

# %%
data_df.iloc[179403]
# Out:
# Invoice                    A506401
# StockCode                        B
# Description        Adjust bad debt
# Quantity                         1
# InvoiceDate    2010-04-29 13:36:00
# Price                    -53594.36
# Customer ID                    NaN
# Country             United Kingdom
# Name: 179403, dtype: object
