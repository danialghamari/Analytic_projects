# %%
import pandas as pd, numpy as np, plotly,os

# %%
cur_dir = os.path.abspath('')
dataset_path = os.path.join(cur_dir,'..','Datasets/online+retail/Processed/online_retail_joined.pkl')

df = pd.read_pickle(dataset_path)

# %%
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0          536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365     71053                  WHITE METAL LANTERN         6
# 2          536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...       ...                                  ...       ...
# 1067365    538171     22271                 FELTCRAFT DOLL ROSIE         2
# 1067366    538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 1067367    538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 1067368    538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 1067369    538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
loyal_customers_df = df[df.CustomerID!=-1]

# %%
customer_recency = loyal_customers_df.groupby("CustomerID",as_index=False)["InvoiceDate"].max()
customer_recency.columns = ["CustomerID","LastPurchaseDate"]
customer_recency["LastPurchaseDate"] = customer_recency["LastPurchaseDate"].dt.normalize()

latest_purchase_date = customer_recency["LastPurchaseDate"].max()

customer_recency["Recency"] = customer_recency["LastPurchaseDate"].apply(
    lambda x: (latest_purchase_date - x).days)

# %%
customer_recency.head()
# Out:
#    CustomerID LastPurchaseDate  Recency
# 0     12346.0       2011-01-18      325
# 1     12347.0       2011-12-07        2
# 2     12348.0       2011-09-25       75
# 3     12349.0       2011-11-21       18
# 4     12350.0       2011-02-02      310

# %%
customer_freq = loyal_customers_df.groupby("CustomerID",as_index=False)["InvoiceDate"].nunique()
customer_freq.columns = ["CustomerID", "Frequency"]

# %%
customer_freq.head()
# Out:
#    CustomerID  Frequency
# 0     12346.0         17
# 1     12347.0          8
# 2     12348.0          5
# 3     12349.0          5
# 4     12350.0          1

# %%
loyal_customers_df["TotalPrice"] = loyal_customers_df["UnitPrice"]*loyal_customers_df["Quantity"]

customer_monetary = loyal_customers_df.groupby("CustomerID",as_index=False)["TotalPrice"].sum()
customer_monetary.columns = ["CustomerID", "Monetary"]

# %%
customer_monetary.head()
# Out:
#    CustomerID  Monetary
# 0     12346.0    -64.68
# 1     12347.0   5598.52
# 2     12348.0   2019.40
# 3     12349.0   4270.48
# 4     12350.0    314.60

# %%
loyal_customers_df.loc[(loyal_customers_df["CustomerID"]==12346.0)
    &
    (loyal_customers_df["Quantity"]<0)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 612989   C495800    ADJUST  ADJUSTMENT BY JOHN ON 26/01/2010 16        -1
# 797495   C514024         M                               MANUAL        -1
# 797496   C514024         M                               MANUAL        -1
# 797497   C514024         M                               MANUAL        -1
# 797498   C514024         M                               MANUAL        -1
# 797499   C514024         M                               MANUAL        -1
# 797500   C514024         M                               MANUAL        -3
# 797501   C514024         M                               MANUAL        -1
# 797502   C514024         M                               MANUAL        -4
# 797503   C514024         M                               MANUAL        -1
# 797504   C514024         M                               MANUAL        -1
# ...

# %%
loyal_customers_df.loc[(loyal_customers_df["CustomerID"]==12347.0)]
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 14938      537626     85116      BLACK CANDELABRA T-LIGHT HOLDER        12
# 14939      537626     22375    AIRLINE BAG VINTAGE JET SET BROWN         4
# 14940      537626     71477    COLOUR GLASS. STAR T-LIGHT HOLDER        12
# 14941      537626     22492              MINI PAINT SET VINTAGE         36
# 14942      537626     22771  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN        12
# ...           ...       ...                                  ...       ...
# 1059811    537626     21064                BOOM BOX SPEAKER BOYS         6
# 1059812    537626     21731        RED TOADSTOOL LED NIGHT LIGHT        12
# 1059813    537626    84558A         3D DOG PICTURE PLAYING CARDS        24
# 1059814    537626     20780            BLACK EAR MUFF HEADPHONES        12
# 1059815    537626     20782       CAMOUFLAGE EAR MUFF HEADPHONES         6
#
# ...
